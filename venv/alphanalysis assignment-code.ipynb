# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\Aditi Bajpai\\Stocks_Analysis\\venv\\data\\stocks_data.csv")

# %%
print(df.head())
# Out:
#        Ticker  Weightage  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0  ADANIPORTS     0.0082         NaN         NaN         NaN         NaN
# 1  APOLLOHOSP     0.0061         NaN         NaN         NaN         NaN
# 2  ASIANPAINT     0.0195         NaN         NaN         NaN         NaN
# 3    AXISBANK     0.0257         NaN         NaN         NaN         NaN
# 4  BAJAJFINSV     0.0120         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         NaN         NaN         NaN         NaN          NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 17  Unnamed: 18  Unnamed: 19
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
df[['Ticker', 'Weightage']]
# Out:
#         Ticker  Weightage
# 0   ADANIPORTS     0.0082
# 1   APOLLOHOSP     0.0061
# 2   ASIANPAINT     0.0195
# 3     AXISBANK     0.0257
# 4   BAJAJFINSV     0.0120
# 5   BAJFINANCE     0.0237
# 6   BHARTIARTL     0.0233
# 7         BPCL     0.0046
# 8    BRITANNIA     0.0052
# 9        CIPLA     0.0068
# 10   COALINDIA     0.0051
# 11    DIVISLAB     0.0077
# 12     DRREDDY     0.0067
# 13   EICHERMOT     0.0049
# 14      GRASIM     0.0085
# 15     HCLTECH     0.0153
# 16    HDFCBANK     0.0810
# 17    HDFCLIFE     0.0072
# 18  HEROMOTOCO     0.0043
# 19    HINDALCO     0.0094
# 20  HINDUNILVR     0.0267
# 21   ICICIBANK     0.0690
# 22  INDUSINDBK     0.0085
# 23        INFY     0.0766
# 24         ITC     0.0303
# 25    JSWSTEEL     0.0094
# 26   KOTAKBANK     0.0351
# 27          LT     0.0274
# 28      MARUTI     0.0137
# 29   NESTLEIND     0.0087
# 30        NTPC     0.0099
# 31        ONGC     0.0078
# 32   POWERGRID     0.0104
# 33    RELIANCE     0.1286
# 34     SBILIFE     0.0065
# 35        SBIN     0.0254
# 36    SHREECEM     0.0046
# 37   SUNPHARMA     0.0134
# 38  TATACONSUM     0.0066
# 39  TATAMOTORS     0.0105
# 40   TATASTEEL     0.0137
# 41         TCS     0.0491
# 42       TECHM     0.0105
# 43       TITAN     0.0137
# 44  ULTRACEMCO     0.0102
# 45         UPL     0.0060
# 46       WIPRO     0.0101

# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (0.2.50)
# Requirement already satisfied: pandas>=1.3.0 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas yfinance openpyxl
# Out:
# Requirement already satisfied: pandas in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (2.2.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: yfinance in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (0.2.50)
# Requirement already satisfied: openpyxl in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: requests>=2.31 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: et-xmlfile in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\aditi bajpai\stocks_analysis\venv\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)

# %%
import pandas as pd
def process_stocks(file_path, start_date, end_date, investment):
    try:
        data = pd.read_csv(file_path)
        print("Columns in CSV:", data.columns)
    except FileNotFoundError:
        print(f"Error: The file {file_path} was not found.")
        return None
    data = data.loc[:, ~data.columns.str.contains('^Unnamed')]
    data = data.dropna(axis=1, how='all')
    required_columns = ['Ticker', 'Weightage']
    for column in required_columns:
        if column not in data.columns:
            print(f"Error: Missing required column '{column}' in the CSV file.")
            return None
    data = data.dropna(subset=['Ticker', 'Weightage'])
    data['Weightage'] = data['Weightage'].astype(float)
    data['Investment'] = data['Weightage'] / 100 * investment
    analysis_data = []
    for _, row in data.iterrows():
        ticker = row['Ticker']
        weightage = row['Weightage']
        investment_for_ticker = row['Investment']
        analysis_data.append({
            'Ticker': ticker,
            'Weightage': weightage,
            str(start_date.date()): 45043,
            str(end_date.date()): 45044,
            'Investment for Ticker': investment_for_ticker,
        })
    analysis_df = pd.DataFrame(analysis_data)
    analysis_df = analysis_df[['Ticker', 'Weightage', str(start_date.date()), str(end_date.date()), 'Investment for Ticker']]
    return analysis_df

if __name__ == "__main__":
    csv_file = "data/stocks_data.csv"
    start_date = input("Enter the start date (YYYY-MM-DD): ")
    end_date = input("Enter the end date (YYYY-MM-DD): ")
    investment = float(input("Enter the investment amount: "))
    try:
        start_date = pd.to_datetime(start_date)
        end_date = pd.to_datetime(end_date)
    except ValueError:
        print("Invalid date format. Please use YYYY-MM-DD.")
        exit(1)
    result_data = process_stocks(csv_file, start_date, end_date, investment)
    if result_data is not None:
        print("\nProcessed Data:\n", result_data)
        output_path = "output/investment_results.xlsx"
        result_data.to_excel(output_path, index=False)
        print(f"\nProcessed data saved to '{output_path}'.")
# Out:
# Columns in CSV: Index(['Ticker', 'Weightage', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')
#
# Processed Data:
#          Ticker  Weightage  2024-05-11  2024-05-12  Investment for Ticker
# 0   ADANIPORTS     0.0082       45043       45044                   2.46
# 1   APOLLOHOSP     0.0061       45043       45044                   1.83
# 2   ASIANPAINT     0.0195       45043       45044                   5.85
# 3     AXISBANK     0.0257       45043       45044                   7.71
# 4   BAJAJFINSV     0.0120       45043       45044                   3.60
# 5   BAJFINANCE     0.0237       45043       45044                   7.11
# 6   BHARTIARTL     0.0233       45043       45044                   6.99
# 7         BPCL     0.0046       45043       45044                   1.38
# 8    BRITANNIA     0.0052       45043       45044                   1.56
# 9        CIPLA     0.0068       45043       45044                   2.04
# 10   COALINDIA     0.0051       45043       45044                   1.53
# 11    DIVISLAB     0.0077       45043       45044                   2.31
# 12     DRREDDY     0.0067       45043       45044                   2.01
# 13   EICHERMOT     0.0049       45043       45044                   1.47
# 14      GRASIM     0.0085       45043       45044                   2.55
# 15     HCLTECH     0.0153       45043       45044                   4.59
# 16    HDFCBANK     0.0810       45043       45044                  24.30
# 17    HDFCLIFE     0.0072       45043       45044                   2.16
# 18  HEROMOTOCO     0.0043       45043       45044                   1.29
# 19    HINDALCO     0.0094       45043       45044                   2.82
# 20  HINDUNILVR     0.0267       45043       45044                   8.01
# 21   ICICIBANK     0.0690       45043       45044                  20.70
# 22  INDUSINDBK     0.0085       45043       45044                   2.55
# 23        INFY     0.0766       45043       45044                  22.98
# 24         ITC     0.0303       45043       45044                   9.09
# 25    JSWSTEEL     0.0094       45043       45044                   2.82
# 26   KOTAKBANK     0.0351       45043       45044                  10.53
# 27          LT     0.0274       45043       45044                   8.22
# 28      MARUTI     0.0137       45043       45044                   4.11
# 29   NESTLEIND     0.0087       45043       45044                   2.61
# 30        NTPC     0.0099       45043       45044                   2.97
# 31        ONGC     0.0078       45043       45044                   2.34
# 32   POWERGRID     0.0104       45043       45044                   3.12
# 33    RELIANCE     0.1286       45043       45044                  38.58
# 34     SBILIFE     0.0065       45043       45044                   1.95
# 35        SBIN     0.0254       45043       45044                   7.62
# 36    SHREECEM     0.0046       45043       45044                   1.38
# 37   SUNPHARMA     0.0134       45043       45044                   4.02
# 38  TATACONSUM     0.0066       45043       45044                   1.98
# 39  TATAMOTORS     0.0105       45043       45044                   3.15
# 40   TATASTEEL     0.0137       45043       45044                   4.11
# 41         TCS     0.0491       45043       45044                  14.73
# 42       TECHM     0.0105       45043       45044                   3.15
# 43       TITAN     0.0137       45043       45044                   4.11
# 44  ULTRACEMCO     0.0102       45043       45044                   3.06
# 45         UPL     0.0060       45043       45044                   1.80
# 46       WIPRO     0.0101       45043       45044                   3.03
#
# Processed data saved to 'output/investment_results.xlsx'.
